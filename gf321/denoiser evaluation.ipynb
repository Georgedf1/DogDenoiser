# %%
import numpy as np
import tensorflow as tf
import dog_denoiser

# %%
dd = dog_denoiser.DogDenoiser()
dd.load_tr_data()

# %%
dd.joint_data
# Out:
# (2090832,)

# %%
# Out:
# 1

# %%
#A little fun test
'''
input_shape = (10,)
layer_num = 5
output_num = 5

a = tf.constant([0,1,2,3,4],dtype=float)

#Flatten inputs
inputs = tf.keras.layers.Input(shape=input_shape)
inputs_flat = tf.keras.layers.Flatten()(inputs)

#First layer
x = tf.keras.layers.Dense(2048, activation='relu')(inputs_flat)

#Residual blocks; layer_num many
for ind in range(layer_num):
    y = tf.keras.layers.Dense(2048)(x) #}
    z = tf.keras.layers.Add()([x, y])  #} ResNet
    x= tf.keras.layers.ReLU()(z)       #}

#Last layer, linear activation for predictions
outputs = tf.keras.layers.Dense(output_num)(x)
scaled = tf.keras.layers.Multiply()([outputs,a])

#Define model
model = tf.keras.Model(inputs=inputs, outputs=outputs)
'''
