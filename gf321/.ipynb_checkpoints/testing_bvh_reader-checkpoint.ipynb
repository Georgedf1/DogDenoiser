# %%
import numpy as np

# %%
from gf321_utils import bvh_utils

# %%
test_data = bvh_utils.BVHData()

# %%
test_data.bvhRead('dog1_trot_skeleton.bvh')
# Out:
# Reading BVH File.. dog1_trot_skeleton.bvh
# Shape of MOTION (147, 210)
# ROOT 1 Count 1
# JOINT Spine01 Line 5 Count 2
# JOINT Spine02 Line 9 Count 3
# JOINT LeftShoulder Line 13 Count 4
# JOINT LeftArm Line 17 Count 5
# JOINT LeftForeArm Line 21 Count 6
# JOINT LeftWrist Line 25 Count 7
# JOINT LeftHand Line 29 Count 8
# JOINT (End Site) 33 Count 9
# Pop Joint - Count 8
# Pop Joint - Count 7
# Pop Joint - Count 6
# Pop Joint - Count 5
# Pop Joint - Count 4
# Pop Joint - Count 3
# JOINT RightShoulder Line 42 Count 4
# JOINT RightArm Line 46 Count 5
# JOINT RightForeArm Line 50 Count 6
# JOINT RightWrist Line 54 Count 7
# JOINT RightHand Line 58 Count 8
# JOINT (End Site) 62 Count 9
# Pop Joint - Count 8
# Pop Joint - Count 7
# Pop Joint - Count 6
# Pop Joint - Count 5
# Pop Joint - Count 4
# Pop Joint - Count 3
# JOINT Neck01 Line 71 Count 4
# JOINT Neck02 Line 75 Count 5
# JOINT Neck03 Line 79 Count 6
# JOINT Neck04 Line 83 Count 7
# JOINT Head Line 87 Count 8
# JOINT (End Site) 91 Count 9
# Pop Joint - Count 8
# JOINT LeftEar Line 95 Count 9
# JOINT (End Site) 99 Count 10
# Pop Joint - Count 9
# Pop Joint - Count 8
# JOINT RightEar Line 104 Count 9
# JOINT (End Site) 108 Count 10
# Pop Joint - Count 9
# Pop Joint - Count 8
# Pop Joint - Count 7
# Pop Joint - Count 6
# Pop Joint - Count 5
# Pop Joint - Count 4
# Pop Joint - Count 3
# Pop Joint - Count 2
# Pop Joint - Count 1
# JOINT LeftLeg Line 120 Count 2
# JOINT LeftLowerLeg Line 124 Count 3
# JOINT LeftAnkle Line 128 Count 4
# JOINT LeftFoot Line 132 Count 5
# JOINT (End Site) 136 Count 6
# Pop Joint - Count 5
# Pop Joint - Count 4
# Pop Joint - Count 3
# Pop Joint - Count 2
# Pop Joint - Count 1
# JOINT RightLeg Line 144 Count 2
# JOINT RightLowerLeg Line 148 Count 3
# JOINT RightAnkle Line 152 Count 4
# JOINT RightFoot Line 156 Count 5
# JOINT (End Site) 160 Count 6
# Pop Joint - Count 5
# Pop Joint - Count 4
# Pop Joint - Count 3
# Pop Joint - Count 2
# Pop Joint - Count 1
# JOINT TailBase Line 168 Count 2
# JOINT Tail1 Line 172 Count 3
# JOINT Tail2 Line 176 Count 4
# JOINT Tail3 Line 180 Count 5
# JOINT Tail4 Line 184 Count 6
# JOINT Tail5 Line 188 Count 7
# JOINT Tail6 Line 192 Count 8
# JOINT (End Site) 196 Count 9
# Pop Joint - Count 8
# Pop Joint - Count 7
# Pop Joint - Count 6
# Pop Joint - Count 5
# Pop Joint - Count 4
# Pop Joint - Count 3
# Pop Joint - Count 2
# Pop Joint - Count 1
# Pop Joint - Count 0

# %%
np.array(test_data.root.transMats)[1][:][:-1]
# Out:
# array([[-9.67914161e-01, -2.39599808e-01,  7.57239049e-02,
#         -1.64358000e+03],
#        [-2.23746037e-01,  9.58942901e-01,  1.74259067e-01,
#          5.76536000e+02],
#        [-1.14367340e-01,  1.51724895e-01, -9.81783921e-01,
#          3.28814000e+02]])

# %%
rot = test_data.getJointAngles(withPos=False)
both = test_data.getJointAngles()
pos = test_data.getJointAngles(withJoints=False)

# %%
rot[0][0]
# Out:
# array([[-0.96791416, -0.23959981,  0.0757239 ],
#        [-0.22374604,  0.9589429 ,  0.17425907],
#        [-0.11436734,  0.1517249 , -0.98178392]])

# %%
both[0][0]
# Out:
# array([[-9.67914161e-01, -2.39599808e-01,  7.57239049e-02,
#         -1.64358000e+03],
#        [-2.23746037e-01,  9.58942901e-01,  1.74259067e-01,
#          5.76536000e+02],
#        [-1.14367340e-01,  1.51724895e-01, -9.81783921e-01,
#          3.28814000e+02]])

# %%
pos[0][0]
# Out:
# array([-1643.58 ,   576.536,   328.814])

# %%
one = np.zeros((3,3))
one[0]=[0,1,2]
one[1]=[1,2,3]
one[2]=[4,5,6]

# %%
one[:-1,:-1]
# Out:
# array([[0., 1.],
#        [1., 2.]])
