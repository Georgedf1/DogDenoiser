# %%
# %matplotlib notebook

# %%
import numpy as np

import augmentation_utils
import marker_utils
import bvh_utils
import plot_utils

# %%
'''
NB: testSeq has different shape in marker data and joint data by 1, could easily be corrected
but for ease I will leave 'testSeq' out of motion_names below
'''
def read_all_bvh():

    motion_names = ['jump','poles','table','trot','walk']

    markers = []
    joints = []

    for name in motion_names:
        bvh_class = bvh_utils.BVHData()
        bvh_class.bvhRead('neural_lbs_data/dog1_' + name + '_skeleton.bvh')
        if joints == []:
            joints = bvh_class.getJointAngles()
            current_joints = joints
            markers = marker_utils.read_markers('neural_lbs_data/dog1_' + name + '_markers.json')
            current_markers = markers
        else:
            current_joints =bvh_class.getJointAngles()
            joints = np.append(joints, current_joints, axis=0)
            current_markers = marker_utils.read_markers('neural_lbs_data/dog1_' + name + '_markers.json')
            markers = np.append(markers, current_markers, axis=0)

        print('Shape equal: ',current_markers.shape[0]==current_joints.shape[0])
        if current_markers.shape[0] != current_joints.shape[0]:
            print('FALSE with joints: ',current_joints.shape[0],'and markers: ',current_markers.shape[0])

    markers, joints = augmentation_utils.augment(markers, joints)       
    
    np.save('full_markers.npy',markers) #[][][][] if else blah
    np.save('full_joints.npy',joints)
    
    
    
    print('Finished')
    print('Joint shape: ',joints.shape)
    print('Marker shape: ',markers.shape)
    
    return markers, joints

#markers, joints = read_all_bvh()

# %%
joints.shape
# Out:
# (2026, 43, 3, 4)

# %%
def read_npy():
    markers = np.load('full_markers.npy')
    joints = np.load('full_joints.npy')
    return markers, joints

markers, joints = read_npy()

root_tfs = bvh_utils.create_local_tfs_root(joints)
markers = marker_utils.make_markers_local(markers,root_tfs)
joints = bvh_utils.make_joints_local(joints)

print('Marker shape: ',markers.shape)
print('Joints shape: ',joints.shape)
# Out:
# Marker shape:  (2026, 64, 3)
# Joints shape:  (2026, 43, 3, 4)

# %%
marker_means = markers.mean(axis=0)
print(marker_means.shape)
marker_stds = markers.std(axis=0)
joint_means = joints.mean(axis=0)
joint_stds = joints.std(axis=0)

markers_n = markers - marker_means
#markers_n = markers_n/marker_stds
plot_utils.plot(markers_n,0)
# Out:
# (64, 3)
# minmaxs are:  -323.64375832181804 100.73598011977332 -193.32399190192353 44.15970970764705 -59.92456596187304 33.297206057380436
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# -2.9863987671428704
